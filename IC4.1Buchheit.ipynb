# %% [markdown]
# <a href="https://colab.research.google.com/github/becca1154b-pixel/MIS2800/blob/main/IC4.1Buchheit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # IMPORTANT ❗
# The below blocks are the lines of code to begin using sqlite3 magic.
#
# This is meant to be reused as needed.  To use, go to File > Save a Copy in Drive.

# %%
# !pip install --upgrade pandas ipython-sql prettytable==3.10.1

# %%
# Install the SQL extension. Remember to type exactly as shown here.
# !pip install ipython-sql
print("ipython sql installed")
# Out:
# ...
# ipython sql installed

# %%
# Load the SQL magic extension
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
#this code imports sqlite3 and prints a statement stating it has been imported
import sqlite3
print("sqlite3 imported")
# Out:
# sqlite3 imported

# %%
# This creates a brand-new, empty database file named [name of your database.db]
conn = sqlite3.connect('nameOfDatabase.db')
print("nameOfDatabase database created")
# Out:
# nameOfDatabase database created

# %%
# This line is required so Colab stops acting like Python and acts more like a SQL database terminal
# %sql sqlite:///nameOfDatabase.db

# %% [markdown]
# # ----SPECIFIC FOR PREP/IC/HW ----

# %%
Build a table. You can make the subject and columns of your own choosing. The table should have at least three columns. The screenshots below may help but will not provide all the needed instructions.

SQL

# %%sql /* 1. Create the table with STRICT types */ CREATE TABLE products ( product_id INTEGER PRIMARY KEY, name TEXT, price REAL ) STRICT; /* 2. Insert at least 3 items (Perform a 'Create' operation) */

INSERT INTO products (name, price) VALUES ('Superbowl Jersey', 120.00);

# %%
# %%sql
# /* Drop the table if it already exists to avoid errors on re-run */
# DROP TABLE IF EXISTS products;
#
# /* Create the products table with STRICT types */
# CREATE TABLE products (
#     product_id INTEGER PRIMARY KEY,
#     name TEXT,
#     price REAL
# ) STRICT;
#
# /* Insert at least 3 items (Perform a 'Create' operation) */
# INSERT INTO products (name, price) VALUES ('Superbowl Jersey', 120.00);
# INSERT INTO products (name, price) VALUES ('Baseball Cap', 25.50);
# INSERT INTO products (name, price) VALUES ('Basketball Shoes', 150.00);
# Out:
#  * sqlite:///nameOfDatabase.db
# Done.
# Done.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# []

# %%
# %%sql /* Show all products that cost more than $50 */ SELECT * FROM products WHERE price > 50;
#
# Task 3: Update and Delete (U & D)
#
# SQL
#
# %%sql /* Update a price */ UPDATE products SET price = 99.99 WHERE name = 'Superbowl Jersey'; /* Delete an item */ DELETE FROM products WHERE product_id = 1;

# %%
# %%sql
# /* Update a price */
# UPDATE products SET price = 99.99 WHERE name = 'Superbowl Jersey';
#
# /* Delete an item */
# DELETE FROM products WHERE product_id = 1;
# Out:
#  * sqlite:///nameOfDatabase.db
# 1 rows affected.
# 1 rows affected.
# []
